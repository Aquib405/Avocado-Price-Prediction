# %% [markdown]
# <a href="https://colab.research.google.com/github/Aquib405/Avocado-Price-Prediction/blob/main/notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Avocado Price Prediction

# %% [markdown]
# ## Importing the Libraries and dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('data.csv',index_col=0)
data.head(10)
# Out:
#          Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0  2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1  2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2  2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3  2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4  2015-11-29          1.28      51039.60   941.48   43838.39   75.78
# 5  2015-11-22          1.26      55979.78  1184.27   48067.99   43.61
# 6  2015-11-15          0.99      83453.76  1368.92   73672.72   93.26
# 7  2015-11-08          0.98     109428.33   703.75  101815.36   80.00
# 8  2015-11-01          1.02      99811.42  1022.15   87315.57   85.34
# 9  2015-10-25          1.07      74338.76   842.40   64757.44  113.00
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  region
# 0     8696.87     8603.62       93.25          0.0  conventional  2015  Albany
# ...

# %% [markdown]
# ## Checking Missing value

# %%
data.isnull().sum()
# Out:
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ### Data info

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18249 entries, 0 to 11
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          18249 non-null  object
#  1   AveragePrice  18249 non-null  float64
#  2   Total Volume  18249 non-null  float64
#  3   4046          18249 non-null  float64
#  4   4225          18249 non-null  float64
#  5   4770          18249 non-null  float64
#  6   Total Bags    18249 non-null  float64
#  7   Small Bags    18249 non-null  float64
#  8   Large Bags    18249 non-null  float64
#  9   XLarge Bags   18249 non-null  float64
#  10  type          18249 non-null  object
#  11  year          18249 non-null  int64
#  12  region        18249 non-null  object
# dtypes: float64(9), int64(1), object(3)
# memory usage: 1.9+ MB

# %% [markdown]
# ### Statistical Description

# %%
data.describe(include = 'all')
# Out:
#               Date  AveragePrice  Total Volume          4046          4225  \
# count        18249  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04
# unique         169           NaN           NaN           NaN           NaN
# top     2015-12-27           NaN           NaN           NaN           NaN
# freq           108           NaN           NaN           NaN           NaN
# mean           NaN      1.405978  8.506440e+05  2.930084e+05  2.951546e+05
# std            NaN      0.402677  3.453545e+06  1.264989e+06  1.204120e+06
# min            NaN      0.440000  8.456000e+01  0.000000e+00  0.000000e+00
# 25%            NaN      1.100000  1.083858e+04  8.540700e+02  3.008780e+03
# 50%            NaN      1.370000  1.073768e+05  8.645300e+03  2.906102e+04
# 75%            NaN      1.660000  4.329623e+05  1.110202e+05  1.502069e+05
# max            NaN      3.250000  6.250565e+07  2.274362e+07  2.047057e+07
#
# ...

# %% [markdown]
# ### Column names

# %%
data.columns
# Out:
# Index(['Date', 'AveragePrice', 'Total Volume', '4046', '4225', '4770',
#        'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type', 'year',
#        'region'],
#       dtype='object')

# %% [markdown]
# ## Distplot to analyse the target variable

# %%
sns.distplot(data['AveragePrice']);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## Countplot to visualize the yearwise distribution of dataset w.r.t type.

# %%
data['type'].unique()
# Out:
# array(['conventional', 'organic'], dtype=object)

# %%
sns.countplot(x='year',hue='type', data=data)
plt.show()

# %% [markdown]
# The number of records available for 2018 is less as compared to other years

# %%
print('Total number of records for each year: ')
data.year.value_counts()
# Out:
# Total number of records for each year:
# 2017    5722
# 2016    5616
# 2015    5615
# 2018    1296
# Name: year, dtype: int64

# %% [markdown]
# ## Boxplot to analyze the target variable w.r.t type feature.

# %%
sns.boxplot(y="type", x="AveragePrice", data=data);

# %% [markdown]
# ## Boxen Plot to analyze the target feature with respect to different years

# %%
data.year=data.year.apply(str)
sns.boxenplot(x="year", y="AveragePrice", data=data);

# %%
data.head()
# Out:
#          Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0  2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1  2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2  2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3  2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4  2015-11-29          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  region
# 0     8696.87     8603.62       93.25          0.0  conventional  2015  Albany
# 1     9505.56     9408.07       97.49          0.0  conventional  2015  Albany
# 2     8145.35     8042.21      103.14          0.0  conventional  2015  Albany
# 3     5811.16     5677.40      133.76          0.0  conventional  2015  Albany
# 4     6183.95     5986.26      197.69          0.0  conventional  2015  Albany

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# #### Mapping string categorical 'type' feature into integer categorical 'type' feature

# %%
data.head()
# Out:
#          Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0  2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1  2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2  2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3  2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4  2015-11-29          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  region
# 0     8696.87     8603.62       93.25          0.0  conventional  2015  Albany
# 1     9505.56     9408.07       97.49          0.0  conventional  2015  Albany
# 2     8145.35     8042.21      103.14          0.0  conventional  2015  Albany
# 3     5811.16     5677.40      133.76          0.0  conventional  2015  Albany
# 4     6183.95     5986.26      197.69          0.0  conventional  2015  Albany

# %%
data['type'].value_counts()
# Out:
# conventional    9126
# organic         9123
# Name: type, dtype: int64

# %% [markdown]
# #### Label Encoding

# %%
from sklearn import preprocessing 
label_encoder = preprocessing.LabelEncoder()
 
data['type']= label_encoder.fit_transform(data['type'])
data['type'].unique()
# Out:
# array([0, 1])

# %%
# Conventional type has been converted into 0 and Organic has been converted into 1.
data['type'].value_counts()
# Out:
# 0    9126
# 1    9123
# Name: type, dtype: int64

# %%
data.head()
# Out:
#          Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0  2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1  2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2  2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3  2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4  2015-11-29          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags  type  year  region
# 0     8696.87     8603.62       93.25          0.0     0  2015  Albany
# 1     9505.56     9408.07       97.49          0.0     0  2015  Albany
# 2     8145.35     8042.21      103.14          0.0     0  2015  Albany
# 3     5811.16     5677.40      133.76          0.0     0  2015  Albany
# 4     6183.95     5986.26      197.69          0.0     0  2015  Albany

# %% [markdown]
# #### Converting Date into datetime format

# %%
data.Date = data.Date.apply(pd.to_datetime)

# %%
# Extracting Month only and dropping Date Column
data['Month']=data['Date'].apply(lambda x:x.month)
data.drop('Date',axis=1,inplace=True)

# %%
data
# Out:
#     AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0           1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1           1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2           0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3           1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4           1.28      51039.60   941.48   43838.39   75.78     6183.95
# ..           ...           ...      ...        ...     ...         ...
# 7           1.63      17074.83  2046.96    1529.20    0.00    13498.67
# 8           1.71      13888.04  1191.70    3431.50    0.00     9264.84
# 9           1.87      13766.76  1191.92    2452.79  727.94     9394.11
# 10          1.93      16205.22  1527.63    2981.04  727.01    10969.54
# 11          1.62      17489.58  2894.77    2356.13  224.53    12014.15
#
#     Small Bags  Large Bags  XLarge Bags  type  year            region  Month
# ...

# %% [markdown]
# #### Mapping months into its integer type

# %%
data.Month = data.Month.map({1:'JAN',2:'FEB',3:'MARCH',4:'APRIL',5:'MAY',6:'JUNE',7:'JULY',8:'AUG',9:'SEPT',10:'OCT',11:'NOV',12:'DEC'})

# %%
data
# Out:
#     AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0           1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1           1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2           0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3           1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4           1.28      51039.60   941.48   43838.39   75.78     6183.95
# ..           ...           ...      ...        ...     ...         ...
# 7           1.63      17074.83  2046.96    1529.20    0.00    13498.67
# 8           1.71      13888.04  1191.70    3431.50    0.00     9264.84
# 9           1.87      13766.76  1191.92    2452.79  727.94     9394.11
# 10          1.93      16205.22  1527.63    2981.04  727.01    10969.54
# 11          1.62      17489.58  2894.77    2356.13  224.53    12014.15
#
#     Small Bags  Large Bags  XLarge Bags  type  year            region Month
# ...

# %% [markdown]
# ## Monthwise distribution of Sales

# %%
plt.figure(figsize=(9,5))
sns.countplot(data['Month'])
plt.title('Monthwise Distribution of Sales',fontdict={'fontsize':25});
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
data.head()
# Out:
#    AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0          1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1          1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2          0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3          1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4          1.28      51039.60   941.48   43838.39   75.78     6183.95
#
#    Small Bags  Large Bags  XLarge Bags  type  year  region Month
# 0     8603.62       93.25          0.0     0  2015  Albany   DEC
# 1     9408.07       97.49          0.0     0  2015  Albany   DEC
# 2     8042.21      103.14          0.0     0  2015  Albany   DEC
# 3     5677.40      133.76          0.0     0  2015  Albany   DEC
# 4     5986.26      197.69          0.0     0  2015  Albany   NOV

# %% [markdown]
# ## Creating dummy variables and concating them into dataframe

# %%
dummies = pd.get_dummies(data[['year','region','Month']],drop_first=True)

# %%
#Shape of dummies
dummies.shape
# Out:
# (18249, 67)

# %%
df_dummies = pd.concat([data[['Total Volume', '4046', '4225', '4770', 'Total Bags',
       'Small Bags', 'Large Bags', 'XLarge Bags', 'type']],dummies],axis=1)

# %%
# Total dataset shape
df_dummies.shape
# Out:
# (18249, 76)

# %%
target = data['AveragePrice']

# %% [markdown]
# ## Splitting and Feature Scaling

# %%
# Splitting data into training and test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df_dummies,target,test_size=0.30)

# Columns need to be scaled
cols_to_std = ['Total Volume', '4046', '4225', '4770', 'Total Bags', 'Small Bags','Large Bags', 'XLarge Bags']

# Feature Scaling
from sklearn.preprocessing import StandardScaler

scaler=StandardScaler()
scaler.fit(X_train[cols_to_std])
X_train[cols_to_std] = scaler.transform(X_train[cols_to_std])
X_test[cols_to_std] = scaler.transform(X_test[cols_to_std])

# %% [markdown]
# ## Building different ML models for evaluating purpose to find out the best performing one.

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
regressors = {
    'Linear Regression' : LinearRegression(),
    'Decision Tree' : DecisionTreeRegressor(),
    'Random Forest' : RandomForestRegressor(),
    'Support Vector Machines' : SVR(gamma=1),
    'K-nearest Neighbors' : KNeighborsRegressor(n_neighbors=1)
}

results=pd.DataFrame(columns=['MAE','MSE','R2-score'])

for method,func in regressors.items():
    model = func.fit(X_train,y_train)
    pred = model.predict(X_test)
    results.loc[method]= [np.round(mean_absolute_error(y_test,pred),3),
                          np.round(mean_squared_error(y_test,pred),3),
                          np.round(r2_score(y_test,pred),3)
                         ]

# %% [markdown]
# ## Evaluating different models using Evaluation metrics

# %%
results
# Out:
#                            MAE    MSE  R2-score
# Linear Regression        0.183  0.059     0.636
# Decision Tree            0.131  0.040     0.750
# Random Forest            0.095  0.019     0.882
# Support Vector Machines  0.121  0.030     0.816
# K-nearest Neighbors      0.102  0.025     0.843

# %%
results.sort_values('R2-score',ascending=False).style.background_gradient(cmap='Oranges',subset=['R2-score'])
# Out:
# <style type="text/css">
# #T_87c16_row0_col2 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_87c16_row1_col2 {
#   background-color: #b33b02;
#   color: #f1f1f1;
# }
# #T_87c16_row2_col2 {
#   background-color: #dc4c03;
#   color: #f1f1f1;
# }
# #T_87c16_row3_col2 {
#   background-color: #fd974a;
#   color: #000000;
# }
# #T_87c16_row4_col2 {
#   background-color: #fff5eb;
#   color: #000000;
# }
# </style>
# <table id="T_87c16_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >MAE</th>
#       <th class="col_heading level0 col1" >MSE</th>
#       <th class="col_heading level0 col2" >R2-score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_87c16_level0_row0" class="row_heading level0 row0" >Random Forest</th>
#       <td id="T_87c16_row0_col0" class="data row0 col0" >0.095000</td>
#       <td id="T_87c16_row0_col1" class="data row0 col1" >0.019000</td>
# ...

# %% [markdown]
# ### We can clearly see Random Forest is Serving best for this problem

# %% [markdown]
# ## Data Cleaning

# %%
#How to handle missing values:
 #   1. Simple Imputer
  #  2. replace
   # 3. fillna
    #4. dropna

# %%
#Converting data into its correct data format
# Out:
#   File "<ipython-input-43-6cfbcc0cb623>", line 1
#     Converting data into its correct data format
#                   ^
# SyntaxError: invalid syntax

# %%
#Removing irrelevant features
    - drop method

# %%
#Removing duplicate records
    - drop method

# %%
#Feature Engineering
    - Encode my object type of dataset.

# %%
#Encoding methods
    - Label Encoding.
    - One Hot Encoding.

# %%
#Label encoding is preferrable when we have two types of values in categorical column 
#One Hot Encoding is preferrable when we have more than two type of values in categorical column

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips['sex'].unique()
# Out:
# ['Female', 'Male']
# Categories (2, object): ['Male', 'Female']

# %%
tips['smoker'].unique()
# Out:
# ['No', 'Yes']
# Categories (2, object): ['Yes', 'No']

# %%
tips['day'].unique()
# Out:
# ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']

# %%
tips['time'].unique()
# Out:
# ['Dinner', 'Lunch']
# Categories (2, object): ['Lunch', 'Dinner']

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lb = LabelEncoder()
tips['sex'] = lb.fit_transform(tips['sex'])

# %%
tips.head()
# Out:
#    total_bill   tip  sex smoker  day    time  size
# 0       16.99  1.01    0     No  Sun  Dinner     2
# 1       10.34  1.66    1     No  Sun  Dinner     3
# 2       21.01  3.50    1     No  Sun  Dinner     3
# 3       23.68  3.31    1     No  Sun  Dinner     2
# 4       24.59  3.61    0     No  Sun  Dinner     4

# %%
tips['smoker'] = lb.fit_transform(tips['smoker'])
tips['time'] = lb.fit_transform(tips['time'])

# %%
tips.head()
# Out:
#    total_bill   tip  sex  smoker  day  time  size
# 0       16.99  1.01    0       0  Sun     0     2
# 1       10.34  1.66    1       0  Sun     0     3
# 2       21.01  3.50    1       0  Sun     0     3
# 3       23.68  3.31    1       0  Sun     0     2
# 4       24.59  3.61    0       0  Sun     0     4

# %%
tips_updated = pd.get_dummies(tips)

# %%
tips_updated
# Out:
#      total_bill   tip  sex  smoker  time  size  day_Thur  day_Fri  day_Sat  \
# 0         16.99  1.01    0       0     0     2         0        0        0
# 1         10.34  1.66    1       0     0     3         0        0        0
# 2         21.01  3.50    1       0     0     3         0        0        0
# 3         23.68  3.31    1       0     0     2         0        0        0
# 4         24.59  3.61    0       0     0     4         0        0        0
# ..          ...   ...  ...     ...   ...   ...       ...      ...      ...
# 239       29.03  5.92    1       0     0     3         0        0        1
# 240       27.18  2.00    0       1     0     2         0        0        1
# 241       22.67  2.00    1       1     0     2         0        0        1
# 242       17.82  1.75    1       0     0     2         0        0        1
# 243       18.78  3.00    0       0     0     2         1        0        0
#
#      day_Sun
# 0          1
# 1          1
# 2          1
# ...

# %%
tips
# Out:
#      total_bill   tip  sex  smoker   day  time  size
# 0         16.99  1.01    0       0   Sun     0     2
# 1         10.34  1.66    1       0   Sun     0     3
# 2         21.01  3.50    1       0   Sun     0     3
# 3         23.68  3.31    1       0   Sun     0     2
# 4         24.59  3.61    0       0   Sun     0     4
# ..          ...   ...  ...     ...   ...   ...   ...
# 239       29.03  5.92    1       0   Sat     0     3
# 240       27.18  2.00    0       1   Sat     0     2
# 241       22.67  2.00    1       1   Sat     0     2
# 242       17.82  1.75    1       0   Sat     0     2
# 243       18.78  3.00    0       0  Thur     0     2
#
# [244 rows x 7 columns]
